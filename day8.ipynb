# %%
print("r")
# Out:
# r

# %%
dict={'aravind':20,"veena":43,"jiva":90,"sam":40}

dict.keys()
dict.values()
dict.get("aravind")


if "aravind" in dict:
    print("yes")

# %%
# to add 
dict["leela"]=30
dict.items()
# Out:
# dict_items([('aravind', 20), ('veena', 43), ('jiva', 90), ('sam', 40), ('leela', 30)])

# %%
set={1,13,54,23,1}
set.add(2)
set
# Out:
# {1, 2, 13, 23, 54}

# %%
#coding task 
contacts={"aravind":6303139689,"baalu":5555555555,"subbama":89756123,"rayadu":123456789,"veena":666666666}
name=input("give me the name : ")

if name in contacts:
    print (f"{contacts[name]} is the number of {name}")
else:
    print("there is nt the a number in the dictionary")
# Out:
# 6303139689 is the number of aravind
