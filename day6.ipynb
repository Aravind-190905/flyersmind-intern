# %%
#assginment 

def fact(n):
    if n == 1:
        return 1
    return n*fact(n-1)

n=int(input("the input is : "))
print(f"{fact(n)} is the factorial of {n}")
# Out:
# 720 is the factorial of 6

# %%
def pal(s:str):
    half=len(s)//2
    if len(s)%2==0:
            if s[0:half] == s[:half:-1]:
                return True
            else:
                    return False
    else:
            if s[0:half] == s[:half:-1]:
                    return True
            else:
                    return False
if pal("devoved"):
    print("yes its is a palindrome")
else:
    print("no it isnt a palindrome")
# Out:
# yes its is a palindrome

# %%
def area(rad):
    return 3.14*rad**2
rad=int(input("rad"))
area(rad)
# Out:
# 78.5

# %%
def evenornot(num):
    if num%2==0:
        return "its even"
    else:
        return "odd it is "
num=int(input("give me num"))
print(evenornot(num))
# Out:
# odd it is
