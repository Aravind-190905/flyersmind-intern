# %%
string="this"
string[0]="d" #as u can its immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 string="this"
# ----> 2 string[0]="d" #as u can its immutable
#
# TypeError: 'str' object does not support item assignment

# %%
string.upper()
string.lower()
# Out:
# 'this'

# %%
# this is for title 
g="   aravind the great.   "
#g.title()
"yes.    ".strip() # remoces the heading and trailing spaces 
id(g)
# Out:
# 2887426563552

# %%
g=g.replace("aravind","aravind subu")
id(g) # as the ids are different they are diffrent
# Out:
# 2887425351856

# %%
# analysing 
g.count("a")# tells u how many times a string has repeated inside another 
g.find("z") # returns the first incident 's index of the substring 
g.startswith("aravind")# used for file extentions 
g.endswith("subu")
# Out:
# False

# %%
import sys
sys.argv[0].endswith("py") # see the file name ends withh py
# Out:
# True

# %%
# spliting and joing 
ls=g.split() # u can have a separator 
g.join(ls)
# Out:
# 'aravind   aravind subu subu the great.   subu   aravind subu subu the great.   subu   aravind subu subu the great.   the   aravind subu subu the great.   great.'

# %%
# list string and set comprehensions 
#li=[expression for item in iterable if condition ]
li=[i for i in range (0,100) if i%2 ==0 and i %20 ==0]
li
# Out:
# [0, 20, 40, 60, 80]

# %%
# we can use join assignment 
# for consonants
sentence="aravind is the greatest"
vowels="aeiouAEIOU"
no_vowels="".join([char for char in sentence if char not in vowels])
no_vowels
# Out:
# 'rvnd s th grtst'

# %%
#only numbers
text="code123"
"".join([char for char in text if char.isdigit() is True])
# Out:
# ['1', '2', '3']

# %%
# lets take a dictionary and get a string from that 

dic={"name":"aravind",
"age":30,
"hobbies":"doing nothing"}

unpac=[char for char in dic.values()]


sti="the name of the person is{} he is {} and does {}".format(*unpac)

sti
# Out:
# 'the name of the person isaravind he is 30 and does doing nothing'

# %%
# string comp
#give me only upper case 
s=input("give me ur string : ")
"".join([char.upper() for char in s ])
# Out:
# '4'

# %%
#gives us the stripped down version
s=input("give me ur string : ")
"".join([char.strip() for char in s ])
# Out:
# 'iam'
